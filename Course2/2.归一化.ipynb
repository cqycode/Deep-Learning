# %% [markdown]
# ![image.png](attachment:347d4430-474d-4602-b372-44350b1dfc60.png)

# %% [markdown]
# 当输入的不同的特征取值范围差异过大，取得对应参数差别也会很大，在对参数进行优化的过程中，参数小的维度步长较小，参数大的维度步长较大，优化过程中路径曲折，将输入归一化，使特征取值范围差别小，对应的参数范围差距小，优化起来更快速。
#
# 对输入进行归一化步骤：
#
# * 特征均值：$$μ=\frac1m\sum_{i=1}^{m}x_i$$ $$x=x-μ$$
#
# * 方差：$$\sigma^2=\frac1m\sum_{i=1}^{m}x_i^2$$ $$x/=\sigma^2$$
#
# * 即可得到均值为0，方差为1的特征分布
#
# 对于特征范围差别不大的无需归一化
