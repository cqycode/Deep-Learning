# %% [markdown]
# ### Momentum梯度下降法
# Momentum梯度下降法的运行速度几乎总是快于标准的梯度下降法。
#
# Momentum梯度下降法的基本思路就是计算梯度的**指数加权平均数**，并利用该梯度更新你的权重。

# %% [markdown]
# ![image.png](attachment:304a10f0-73e9-4427-96a1-cbeab3d684fb.png)

# %% [markdown]
# ![image.png](attachment:eaf57123-9fab-4405-8fd5-a73af822098f.png)
