# %% [markdown]
# ### 学习率衰减
# 学习率衰减：加快学习算法的一个办法就是随时间慢慢减小学习率。
#
# 如果我们不使用学习率衰减，那么算法会在最小值附近大幅度的摆动，而不能收敛。

# %% [markdown]
# 符号说明，
# - $decay-rate$为衰减率。
# - $epoch-num$为已经进行epoch的次数。
# - $\alpha_0$为初始学习率。
# - $\alpha$为更新后的学习率。
#
# #### 方式1
# $$α=\frac{1}{1+decay−rate∗epoch−num}$$
#
# #### 方式2
# 指数衰减：$$α=0.95^{epoch−num}*α^0$$
#
# #### 方式3
# $$α=\frac{k}{\sqrt{epoch−num}}*α^0$$
#
# #### 方式4
# 离散下降的学习率，也就是各个步骤有其自己特定的学习率。学习率呈离散下降：
# ![image.png](attachment:d5c4816b-8936-4c54-925e-87dd61a2f0fe.png)
#
# #### 方式5
# 除了上述方式外，也可以手动衰减，即人为的调整学习率。

# %% [markdown]
# ### 局部最优问题
# ![image.png](attachment:f65a876b-75c6-479d-9769-0848f32888dd.png)
# 人们通常认为cost function的图像会像上图一样，存在很多局部最优点。而优化算法会被困在其中一个局部最优点，而无法达到全局最优点。
#
# 但实际情况是，上述现象只在参数很少的时候容易出现，比如只有两个参数$w_1,w_2$。当我们有很多参数时，在梯度为0且每个方向都是凸函数的点（即局部最优点）是很难出现的。更多的是当梯度为0时，有的方向是凸函数，有的方向是凹函数，即鞍点。
# ![image.png](attachment:56170e9e-9bef-4641-b454-c0f59dbafdf1.png)
# 因此，当我们在训练较大的神经网络，存在大量参数，并且cost function被定义在较高的维度空间时，优化算法不太可能困在局部最优中。
